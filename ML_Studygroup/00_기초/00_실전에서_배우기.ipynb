# %%
import pandas as pd
import numpy as np
import sys
import os

# %%
D=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\공부파일들\excel\한국복지패널\공부용.csv")
D.drop(D.columns[:2],axis=1,inplace=True)
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_19708\24473341.py:1: DtypeWarning: Columns (831,834,836) have mixed types. Specify dtype option on import or set low_memory=False.
#   D=pd.read_csv(r"C:\Users\SAMSUNG\Desktop\공부파일들\excel\한국복지패널\공부용.csv")

# %%
# Out:
#        가구형태/주거급여 수급형태_x  6. 주거/이사경험 여부_x  6. 주거/이사 사유_x  6. 주거/주택유형_x  \
# 0                     0              2.0            NaN             2
# 1                     0              2.0            NaN             2
# 2                     0              2.0            NaN             1
# 3                     0              2.0            NaN             2
# 4                     0              2.0            NaN             2
# ...                 ...              ...            ...           ...
# 68521                 0              2.0            NaN             5
# 68522                 0              2.0            NaN             5
# 68523                 0              2.0            NaN             5
# 68524                 0              2.0            NaN             5
# 68525                 0              2.0            NaN             5
#
#        6. 주거/주거위치_x  6. 주거/방수_x  6. 주거/주거면적_x  6. 주거/집의 (등기상) 점유형태_x  \
# ...
