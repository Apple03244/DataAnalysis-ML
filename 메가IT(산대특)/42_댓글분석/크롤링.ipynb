# %%
url='https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1={category}#&date=%2000:00:00&page={page}'
category_dict=dict(zip(["IT","경제","사회","생활","세계","정치"],[105,101,102,103,104,100]))

# %%
import sys
import os

# %%
os.chdir("C:/Users/SAMSUNG/Desktop/데이터/")

# %%
import requests
import bs4

# %%
All_data_set={}

# %%
session=requests.Session()
session.headers.update({"User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36',
                        'Referer':""})

# %%
CATEGORY = category_dict["IT"]

# 수집하고자하는 페이지 범위
PAGES = range(1, 10)


# 수집한 뉴스기사의 수를 저장할 변수
counter = 1

# 수집한 뉴스기사를 저장할 파일명
fileName = "C:/Users/SAMSUNG/Desktop/데이터/{myname}_naver_news_{category}_{counter}.txt"

# 주어진 카테고리에 대해 주어진 페이지 범위만큼 뉴스 수집
for page in PAGES:
    targetUrl = url.format(category=CATEGORY, page=page)
    print(targetUrl)
    
    # 생성한 접속객체를 활용하여 뉴스 목록 페이지에 접속
    r = session.get(targetUrl)
    
    # 접속에 실패한 경우
    if r.status_code != 200:
        # 에러코드와 에러메시지 출력
        msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
        # 에러를 강제로 생성시킴
        raise Exception(msg)
    
    # 응답결과를 텍스트로 변환
    r.encoding = "euc-kr"
    soup = bs4.BeautifulSoup(r.text)
    #print(soup)
    
    # 뉴스 기사 제목을 위한 CSS 선택자
    selector = ".sh_item .sh_text .sh_text_headline, #section_body ul li dl dt a"
    
    # 뉴스기사 제목 추출
    headlines = soup.select(selector)
    #print(headlines)
    
    # 각 페이지별로 추출된 뉴스기사의 본문 URL
    for h in headlines:
        href = h.attrs["href"]
        
        # 기사 본문에 대한 세부 내용 수집
        if href:
            print(href)
            bodyRes = session.get(href)
            
            # 접속에 실패한 경우
            if bodyRes.status_code != 200:
                # 에러코드와 에러메시지 출력
                msg = "[%d Error] %s 에러가 발생함" % (bodyRes.status_code, bodyRes.reason)
                # 에러를 강제로 생성시킴
                raise Exception(msg)
            
            bodyRes.encoding = "utf-8"
            bodySoup = bs4.BeautifulSoup(bodyRes.text)
            
            # 제목
            title = bodySoup.select("#title_area span")[0].text
            print(title)
            
            # 본문
            content = bodySoup.select("#dic_area")[0]
            
            # 본문 요소에 포함되어 있는 불필요 항목 제거
            for target in content.find_all("span", {"class": "end_photo_org"}):
                target.extract()
                
            for target in content.find_all("strong", {"class": "media_end_summary"}):
                target.extract()
                
            for target in content.find_all("table", {"class": "nbd_table"}):
                target.extract()
                
            for target in content.find_all("div", {"class": "highlightBlock"}):
                target.extract()
                
            for target in content.find_all("div", {"style": "display:none;"}):
                target.extract()
                
            for target in content.find_all("br"):
                target.replace_with("\n")
                
            contentBody = content.text.strip()
            
            with open(fileName.format(myname="LeeJeungHun", category=CATEGORY, counter=counter), "w", encoding="utf-8") as f:
                f.write(title)
                f.write("\n\n")
                f.write(contentBody)
                
            counter += 1
            
            print("%d news article crawled" % counter)
# Out:
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=1
# https://n.news.naver.com/mnews/article/001/0014199517?sid=105
# 네이버 자율규제위 출범…위원장 권헌영 고려대 교수
# 2 news article crawled
# https://n.news.naver.com/mnews/article/011/0004239361?sid=105
# SKB-넷플릭스, 망사용료 합의점 도출한다
# 3 news article crawled
# https://n.news.naver.com/mnews/article/092/0002305400?sid=105
# 저궤도 위성통신 시범망 구축…"수출 30억 달러 달성"
# 4 news article crawled
# https://n.news.naver.com/mnews/article/008/0004939471?sid=105
# 배그 국가대항전 'PNC 2023', 韓 대표팀 첫 우승
# 5 news article crawled
# https://n.news.naver.com/mnews/article/003/0012095366?sid=105
# 더존비즈온, 정밀의료 빅데이터 플랫폼 역량 세계 입증
# 6 news article crawled
# https://n.news.naver.com/mnews/article/469/0000760984?sid=105
# 애플 금지령에도...아이폰15, 중국 예약판매 시작 1분 만에 '완판'
# 7 news article crawled
# https://n.news.naver.com/mnews/article/001/0014199522?sid=105
# 방통위, 신속심의 확대 등 가짜뉴스 근절 패스트트랙 가동
# 8 news article crawled
# https://n.news.naver.com/mnews/article/018/0005577636?sid=105
# '과학기술정보통신 사이버안전센터' 세종으로 이전
# 9 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=2
# https://n.news.naver.com/mnews/article/366/0000932996?sid=105
# 네이버, ‘이용자보호 및 자율규제위원회’ 출범
# 10 news article crawled
# https://n.news.naver.com/mnews/article/031/0000773573?sid=105
# 中 아이폰 금지령에도…아이폰15, 예약 판매 1분 만에 매진
# 11 news article crawled
# https://n.news.naver.com/mnews/article/421/0007056748?sid=105
# SKT, 동반성장지수 11년 연속 최우수…'최우수 명예기업 선정'
# 12 news article crawled
# https://n.news.naver.com/mnews/article/023/0003788480?sid=105
# 넷플릭스-SK브로드밴드, 3년 넘게 이어온 ‘망이용료’ 소송 취하
# 13 news article crawled
# https://n.news.naver.com/mnews/article/277/0005315672?sid=105
# NHN커머스, 中 커머스 기업 '신쉔'과 글로벌 유통사업 제휴
# 14 news article crawled
# https://n.news.naver.com/mnews/article/011/0004239458?sid=105
# 데브시스터즈 신작 '쿠키런: 모험의 탑' 공개…지스타 출품
# 15 news article crawled
# https://n.news.naver.com/mnews/article/009/0005188009?sid=105
# 더존비즈온, 정밀의료 빅데이터 플랫폼 역량 세계 입증
# 16 news article crawled
# https://n.news.naver.com/mnews/article/008/0004939471?sid=105
# 배그 국가대항전 'PNC 2023', 韓 대표팀 첫 우승
# 17 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=3
# https://n.news.naver.com/mnews/article/018/0005577448?sid=105
# 4800억 '위성통신' R&D 나선다..스페이스X 주도 시장 대응
# 18 news article crawled
# https://n.news.naver.com/mnews/article/001/0014199510?sid=105
# SKT·KT, 동반성장지수 최우수 등급 획득
# 19 news article crawled
# https://n.news.naver.com/mnews/article/016/0002199168?sid=105
# 망 이용대가 분쟁, 3년만에 마침표…넷플릭스-SKT-SKB, 손 잡았다
# 20 news article crawled
# https://n.news.naver.com/mnews/article/001/0014199044?sid=105
# 구글플레이, 4년만에 지스타 참가…데브시스터즈 등 신작 공개
# 21 news article crawled
# https://n.news.naver.com/mnews/article/277/0005315662?sid=105
# 네이버, '이용자보호·자율규제위원회' 공식 출범
# 22 news article crawled
# https://n.news.naver.com/mnews/article/006/0000119889?sid=105
# 방통위, 가짜뉴스 근절하겠다며 '심의 패스트트랙' 예고
# 23 news article crawled
# https://n.news.naver.com/mnews/article/030/0003136857?sid=105
# 게임엔진 '유니티' 요금제 개편 파장... 국회 국정감사 부른다
# 24 news article crawled
# https://n.news.naver.com/mnews/article/018/0005576850?sid=105
# 사이버국방학과 졸업생 23명중 4명만 임관…“대책 필요”
# 25 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\SAMSUNG\Desktop\DataAnalysis\42_댓글분석\크롤링.ipynb Cell 7 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/SAMSUNG/Desktop/DataAnalysis/42_%EB%8C%93%EA%B8%80%EB%B6%84%EC%84%9D/%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb#W6sZmlsZQ%3D%3D?line=27'>28</a> # 응답결과를 텍스트로 변환
#      <a href='vscode-notebook-cell:/c%3A/Users/SAMSUNG/Desktop/DataAnalysis/42_%EB%8C%93%EA%B8%80%EB%B6%84%EC%84%9D/%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb#W6sZmlsZQ%3D%3D?line=28'>29</a> r.encoding = "euc-kr"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/SAMSUNG/Desktop/DataAnalysis/42_%EB%8C%93%EA%B8%80%EB%B6%84%EC%84%9D/%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb#W6sZmlsZQ%3D%3D?line=29'>30</a> soup = bs4.BeautifulSoup(r.text)
#      <a href='vscode-notebook-cell:/c%3A/Users/SAMSUNG/Desktop/DataAnalysis/42_%EB%8C%93%EA%B8%80%EB%B6%84%EC%84%9D/%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb#W6sZmlsZQ%3D%3D?line=30'>31</a> #print(soup)
#      <a href='vscode-notebook-cell:/c%3A/Users/SAMSUNG/Desktop/DataAnalysis/42_%EB%8C%93%EA%B8%80%EB%B6%84%EC%84%9D/%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb#W6sZmlsZQ%3D%3D?line=31'>32</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/SAMSUNG/Desktop/DataAnalysis/42_%EB%8C%93%EA%B8%80%EB%B6%84%EC%84%9D/%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb#W6sZmlsZQ%3D%3D?line=32'>33</a> # 뉴스 기사 제목을 위한 CSS 선택자
#      <a href='vscode-notebook-cell:/c%3A/Users/SAMSUNG/Desktop/DataAnalysis/42_%EB%8C%93%EA%B8%80%EB%B6%84%EC%84%9D/%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb#W6sZmlsZQ%3D%3D?line=33'>34</a> selector = ".sh_item .sh_text .sh_text_headline, #section_body ul li dl dt a"
#
# File c:\Users\SAMSUNG\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File c:\Users\SAMSUNG\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File c:\Users\SAMSUNG\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\builder\_lxml.py:378, in LXMLTreeBuilder.feed(self, markup)
#     376 try:
#     377     self.parser = self.parser_for(encoding)
# --> 378     self.parser.feed(markup)
#     379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# File src\lxml\parser.pxi:1259, in lxml.etree._FeedParser.feed()
#
# File src\lxml\parser.pxi:1379, in lxml.etree._FeedParser.feed()
#
# File src\lxml\parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src\lxml\parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src\lxml\etree.pyx:334, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src\lxml\saxparser.pxi:443, in lxml.etree._handleSaxTargetStartNoNs()
#
# File src\lxml\saxparser.pxi:458, in lxml.etree._callTargetSaxStart()
#
# File src\lxml\parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File c:\Users\SAMSUNG\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\builder\_lxml.py:290, in LXMLTreeBuilderForXML.start(self, name, attrs, nsmap)
#     288 new_attrs = {}
#     289 for attr, value in list(attrs.items()):
# --> 290     namespace, attr = self._getNsTag(attr)
#     291     if namespace is None:
#     292         new_attrs[attr] = value
#
# File c:\Users\SAMSUNG\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\builder\_lxml.py:141, in LXMLTreeBuilderForXML._getNsTag(self, tag)
#     138     self.active_namespace_prefixes = [dict(self.DEFAULT_NSMAPS)]
#     139     super(LXMLTreeBuilderForXML, self).__init__(**kwargs)
# --> 141 def _getNsTag(self, tag):
#     142     # Split the namespace URL out of a fully-qualified lxml tag
#     143     # name. Copied from lxml's src/lxml/sax.py.
#     144     if tag[0] == '{':
#     145         return tuple(tag[1:].split('}', 1))
#
# KeyboardInterrupt:
