# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
plt.rcParams["font.family"]="BM YEONSUNG"

# %%
Data=pd.read_excel(r"C:\Users\SAMSUNG\Desktop\변수전처리완료.xlsx")

# %%
data=pd.DataFrame(Data)

# %%
data.head(2)
# Out:
#    Unnamed: 0  가구원수  근로유형  삶의 사다리 점수  가족생활에 대한 만족도  주거위치  식료품비-가정식비  식료품비-외식비  \
# 0           0     1     4          6             4     3       50.0      30.0
# 1           1     1     1          5             6     3       40.0      25.0
#
#    성별  교육수준  건강상태  만성질환  나이  종교  총식료품비  혼인상태
# 0   2     4     4     3  77   0   80.0     2
# 1   1     3     5     3  74   0   65.0     2

# %%
data.drop(data.columns[0:2],inplace=True,axis=1)

# %%
Y=data["삶의 사다리 점수"]
X=data[data.columns.difference(["삶의 사다리 점수"])]

# %%
X
# Out:
#       가족생활에 대한 만족도  건강상태  교육수준  근로유형  나이  만성질환  성별  식료품비-가정식비  식료품비-외식비  종교  \
# 0                4     4     4     4  77     3   2       50.0      30.0   0
# 1                6     5     3     1  74     3   1       40.0      25.0   0
# 2                2     2     7     1  80     3   1       40.0       3.0   0
# 3                4     4     3     1  82     3   2       30.0       3.0   0
# 4                0     3     6     4  60     0   1       35.0       2.0   0
# ...            ...   ...   ...   ...  ..   ...  ..        ...       ...  ..
# 3614             6     2     3     1  79     3   2       28.0       4.0   0
# 3615             6     2     3     1  79     3   2       28.0       5.0   0
# 3616             6     3     2     1  86     3   2       24.0       2.0   0
# 3617             6     2     3     1  79     3   2       28.0       5.0   0
# 3618             6     2     3     4  85     3   1       32.0      10.0   0
#
#       주거위치  총식료품비  혼인상태
# 0        3   80.0     2
# ...

# %%
plt.figure()
sb.countplot(data=X,x=X["가족생활에 대한 만족도"])
plt.show()
plt.close()
